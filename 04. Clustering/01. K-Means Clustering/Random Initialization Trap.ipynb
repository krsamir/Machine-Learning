# %%
from IPython.display import Image

# %%
Image(filename="C:\\Users\\Samir\\Documents\\@asnapshot\\image1.jpg",height=500,width=500)

# %% [markdown]
# By looking at this pic we can say which three clusters will be selected.

# %%
Image(filename="C:\\Users\\Samir\\Documents\\@asnapshot\\image2.jpg",height=500,width=500)

# %% [markdown]
# If we select our centroids in that way our algorithm will converge very quickly.

# %% [markdown]
# ***

# %% [markdown]
# **What would happen if we had a bad random initialisation?**

# %%
Image(filename="C:\\Users\\Samir\\Documents\\@asnapshot\\image3.jpg",height=500,width=500)

# %% [markdown]
# The points will be coloured according to there distance from the centroids.

# %% [markdown]
# The final clusters will be like this.

# %%
Image(filename="C:\\Users\\Samir\\Documents\\@asnapshot\\image4.jpg",height=500,width=500)

# %% [markdown]
# So the clusters which have now formed due to random selection of centroids are different from the determined clusters as we have thought of.<br>
# **Selection of centroids at very start of the algorithm** can potentially dictate the **outcome of the model**.<br>
# That is not good thing because centroids are selected at random.<br>
# How can we overcome this ??<br>
# There is a modification to **k-means** algorithm i.e. we use **k-mean++** algorithm to correcty select the centroids.
