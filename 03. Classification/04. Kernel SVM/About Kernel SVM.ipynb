# %% [markdown]
# There can be two types of classifications :

# %% [markdown]
# 1) Linearly Separable

# %% [markdown]
# 2)Non-linearly separable

# %% [markdown]
# # Mapping to a Higher Dimension

# %% [markdown]
# What we will learn ?

# %% [markdown]
# we will learn how we can take our **non-linearly** separable data-set, **map it to higher dimension** and get a **linearly separable** data-set.

# %% [markdown]
# Invoke the support vector machine algorithm, build a decision boundary for a dataset and then **project all of that back into our original dimension**.

# %% [markdown]
# In 1-d -> the classifier is a **point**.<br>
# In 2-d -> the classifier is a **line**.<br>
# In 3-d -> the classifier is a **hyperplane**.

# %% [markdown]
# **Approach :**

# %% [markdown]
# let this dataset be plotted on a line as such

# %% [markdown]
# |11111    0000000    1111111

# %% [markdown]
# Let the point where the 1 and 0 gets firstly differentiated be at 5 units.<br>
# So let there be a function such that `f = X-5`, So the points which are less than 5 will go on the other side of the coordinates(negative coordinate)

# %% [markdown]
# 11111 | 0000000    1111111

# %% [markdown]
# Then project these points on some higher functions.<br>
# Now see that if they are linearly separable or not.<br>
# If yes then that is the separator.<br>
# Then project every point to its original Space.

# %% [markdown]
# # The kernel Trick

# %% [markdown]
# Formula : Refer to the image.

# %% [markdown]
# # The Gaussian RBF(Radial Basis function) Kernal

# %% [markdown]
# **also called Gaussian Function.**

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# **K** -> Kernel,It is function applied to two vectors.<br>
# **X** -> vector,It is some sort of point in our dataset.<br>
# **i** -> Landmark,<br>
# **e** -> exponential power<br>
# (||x-(l^i)||)^2 -> It is the distance between X and the landmark which is squared.

# %% [markdown]
# refer to -> http://www.cs.toronto.edu/~duvenaud/cookbook/index.html

# %% [markdown]
# The landmark is at the base of the graph. The result is on the vertical plane.

# %% [markdown]
# **Reference to the graph**

# %% [markdown]
# ![Sqaured-exp%20kernel%20in%202d.png](attachment:Sqaured-exp%20kernel%20in%202d.png)

# %% [markdown]
# The peak of the graph lies right in the centre of the whole graph. If we will project that on the bottom then we are going to call it a landmark.<br><br>
# Let there be a point which is far from the middle.<br>
# We take that distance where squaring the distance and dividing it by 2 times sigma squared and then taking the negative we will see what the result will be. <br>
# Let the point taken be a large number and if we square it we will even get a larger number

# %% [markdown]
# So a large negative number when raised to the power of e(exponent) nearly equals to 0.

# %% [markdown]
# If the point is closer to the landmark, so the distance will be small.<br>
# So e raised to a small negative power will somewhat a give a result near to 1.

# %% [markdown]
# So this approves that the function is associated with the graph referenced with.

# %% [markdown]
# ***

# %% [markdown]
# Question arises Why do we need this ?

# %% [markdown]
# ![Capture2.PNG](attachment:Capture2.PNG)

# %% [markdown]
# We use this kernel function to separate our dataset to build that decision boudary.

# %% [markdown]
# The circle in the graph that we are are refering can be seen projected in the dataset.<br>
# anything outside the circumference will be assigned to 0 or very close to zero.If some value fall within the circumference based on the function it will get value above 0.And that is how we separate two classes.

# %% [markdown]
# **Function of Sigma**<br>
# Sigma defines how wide the circumference will be.<br>
# big sigma value means big circum.<br>
# small sigma value means small circum.<br>

# %% [markdown]
# # Types of kernels

# %% [markdown]
# 1) Gaussian RBF kernel<br>
# 2) Sigmoid Kernel<br>
# 3) Polynomial Kernel<br>
# and many more
